# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

data = {
    "Age": [25, 30, np.nan, 45, 50],
    "Salary": [50000, np.nan, 60000, 80000, np.nan],
    "City": ["Delhi", "Mumbai", "Delhi", np.nan, "Chennai"]
}

df = pd.DataFrame(data)
df
# Out:
#     Age   Salary     City
# 0  25.0  50000.0    Delhi
# 1  30.0      NaN   Mumbai
# 2   NaN  60000.0    Delhi
# 3  45.0  80000.0      NaN
# 4  50.0      NaN  Chennai

# %%
df.isnull().sum()
# Out:
# Age       1
# Salary    2
# City      1
# dtype: int64

# %%
df.isnull().sum().plot(kind='bar')
import matplotlib.pyplot as plt
plt.title("Missing Values")
plt.show()

# %%
num_cols = df.select_dtypes(include=np.number).columns
cat_cols = df.select_dtypes(include='object').columns

num_cols, cat_cols
# Out:
# (Index(['Age', 'Salary'], dtype='object'), Index(['City'], dtype='object'))

# %%
for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)

for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

df
# Out:
# /tmp/ipython-input-923169507.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /tmp/ipython-input-923169507.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
#     Age   Salary     City
# 0  25.0  50000.0    Delhi
# 1  30.0  60000.0   Mumbai
# 2  37.5  60000.0    Delhi
# 3  45.0  80000.0    Delhi
# 4  50.0  60000.0  Chennai

# %%
df.isnull().sum()
# Out:
# Age       0
# Salary    0
# City      0
# dtype: int64

# %%
df.to_csv("cleaned_dataset.csv", index=False)
